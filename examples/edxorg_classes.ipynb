# %%
# %matplotlib inline
Out['e07282'][:10].plot('bar')

# %%
# %matplotlib inline
Out['e07282'][Out['8ebbc5']-10:].plot('bar')

# %%
Out['959c24'][[0,3,4,5,6,7,8,9]].sum()
# Out:
# 1107288

# %%
Out['091fec']['Participants (Course Content Accessed)'].sort_values()[Out['8ebbc5']-10:]
# Out:
# Course Title
# Introduction to Computer Science and Programming                   57147
# Justice                                                            58779
# Science and Cooking: From Haute Cuisine to Soft Matter Science     60555
# Introduction to Computer Science and Programming                   62709
# Introduction to Computer Science and Programming Using Python      63658
# Introduction to Computer Science and Programming                   65380
# Introduction to Computer Science                                  129400
# Introduction to Computer Science (2016)                           168335
# Introduction to Computer Science                                  259577
# Introduction to Computer Science                                  301082
# Name: Participants (Course Content Accessed), dtype: int64

# %%
Out['beaccd'][:10]
# Out:
# Course Title
# Flight Vehicle Aerodynamics                                                  22.0
# Circuits and Electronics: Amplification, Speed, and Delay                    23.0
# Advanced Introductory Classical Mechanics                                    23.0
# Introduction to Computer Science (2016)                                      23.0
# Introduction to Aerodynamics                                                 23.0
# Advanced Introductory Classical Mechanics                                    24.0
# Computation Structures: Digital Circuits                                     24.0
# Principles of Biochemistry                                                   24.0
# Introduction to Aerospace Engineering: Astronautics and Human Spaceflight    24.0
# Circuits and Electronics: Amplification, Speed, and Delay                    24.0
# Name: Median Age, dtype: float64

# %%
Out['beaccd'][Out['8ebbc5']-10:]
# Out:
# Course Title
# History of the Book: The Medieval Book of Hours: Art and Devotion in the Later Middle Ages                         38.0
# Poetry in America: Emily Dickinson                                                                                 38.0
# Transforming Business, Society, and Self                                                                           38.0
# Poetry in America: The Civil War and Its Aftermath                                                                 39.0
# History of the Book: Monasteries, Schools, and Notaries, Part 2: Introduction to the Transitional Gothic Script    39.0
# World Religions Through their Scriptures: Religious Literacy, Traditions and Scriptures                            39.0
# Transforming Business, Society, and Self                                                                           39.0
# First Nights: L'Orfeo                                                                                              40.0
# ...

# %%
Out['647803'].mean()
# Out:
#                  Year  Honor Code Certificates  \
# Institution
# HarvardX     3.209302                 0.844961
# MITx         3.142857                 0.788820
#
#              Participants (Course Content Accessed)  \
# Institution
# HarvardX                                16287.75969
# MITx                                    14588.42236
#
#              Audited (> 50% Course Content Accessed)   Certified  % Audited  \
# Institution
# HarvardX                                 2838.457364  837.170543  31.951318
# MITx                                     2317.385093  849.130435  19.280745
#
#              % Certified  % Certified of > 50% Course Content Accessed  \
# Institution
# HarvardX       10.942093                                     33.918450
# MITx            5.251056                                     29.464348
#
#              % Posted in Forum  % Grade Higher Than Zero  \
# Institution
# HarvardX             12.241008                 21.532636
# ...

# %%
len(Out['091fec'])
# Out:
# 290

# %%
import pandas as pd
pd.read_csv("appendix.csv", index_col=3)
# Out:
#                                                    Institution Course Number  \
# Course Title
# Circuits and Electronics                                  MITx        6.002x
# Introduction to Computer Science and Programming          MITx         6.00x
# Introduction to Solid State Chemistry                     MITx        3.091x
# Introduction to Computer Science                      HarvardX         CS50x
# Health in Numbers: Quantitative Methods in Clin...    HarvardX        PH207x
# Introduction to Computer Science and Programming          MITx         6.00x
# Introduction to Solid State Chemistry                     MITx        3.091x
# The Challenges of Global Poverty                          MITx        14.73x
# Electricity and Magnetism                                 MITx         8.02x
# Justice                                               HarvardX         ER22x
# Circuits and Electronics                                  MITx        6.002x
# ...

# %%
Out['091fec'].index
# Out:
# Index(['Circuits and Electronics',
#        'Introduction to Computer Science and Programming',
#        'Introduction to Solid State Chemistry',
#        'Introduction to Computer Science',
#        'Health in Numbers: Quantitative Methods in Clinical and Public Health Research',
#        'Introduction to Computer Science and Programming',
#        'Introduction to Solid State Chemistry',
#        'The Challenges of Global Poverty', 'Electricity and Magnetism',
#        'Justice',
#        ...
#        'Circuits and Electronics: Basic Circuit Analysis',
#        'Circuits and Electronics: Amplification, Speed, and Delay',
#        'Optical Materials and Devices',
#        'World Religions Through their Scriptures: Hinduism',
#        'Implementation and Evaluation of Educational Technology',
#        'First Nights: Symphonie Fantastique',
#        'Introduction to Family Engagement in Education',
#        'Introduction to Control System Design',
# ...

# %%
Out['091fec']['% Male'].sort_values()
# Out:
# Course Title
# Introduction to Family Engagement in Education                                                                     25.24
# Poetry in America: Emily Dickinson                                                                                 33.26
# History of the Book: Book Sleuthing: What 19th-Century Books Can Tell Us About the Rise of the Reading Public      33.38
# Tangible Things                                                                                                    34.31
# Introduction to Data Wise: A Collaborative Process to Improve Learning and Teaching                                35.31
# World Religions Through their Scriptures: Religious Literacy, Traditions and Scriptures                            36.96
# Practical Improvement Science in Health Care: A Roadmap for Getting Results                                        37.24
# Tangible Things                                                                                                    37.38
# ...

# %%
Out['091fec']['Median Age'].sort_values()
# Out:
# Course Title
# Flight Vehicle Aerodynamics                                                                                        22.0
# Circuits and Electronics: Amplification, Speed, and Delay                                                          23.0
# Advanced Introductory Classical Mechanics                                                                          23.0
# Introduction to Computer Science (2016)                                                                            23.0
# Introduction to Aerodynamics                                                                                       23.0
# Advanced Introductory Classical Mechanics                                                                          24.0
# Computation Structures: Digital Circuits                                                                           24.0
# Principles of Biochemistry                                                                                         24.0
# ...

# %%
Out['091fec'].groupby("Institution")
