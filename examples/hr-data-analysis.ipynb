# %% [markdown]
# # Left is a boolean that an employee has left the company, as we can see Accounting Staff have a much higher leave percentage than Management.

# %%
# %matplotlib inline
Out['1f16bb'].plot(kind="bar")

# %%
Out['7dc400']['left']
# Out:
# sales
# IT             0.222494
# RandD          0.153748
# accounting     0.265971
# hr             0.290934
# management     0.144444
# marketing      0.236597
# product_mng    0.219512
# sales          0.244928
# support        0.248991
# technical      0.256250
# Name: left, dtype: float64

# %% [markdown]
# # Let's say we want to see if there's any outliers, let's take a look at the employee with the longest time since their last evaluation, they've spent 5 years at the company are in sales and work well above the mean number of hours for someone in their career.

# %%
Out['372b0d'].iloc[Out['372b0d']['last_evaluation'].idxmax()]
# Out:
# satisfaction_level        0.89
# last_evaluation              1
# number_project               5
# average_montly_hours       224
# time_spend_company           5
# Work_accident                0
# left                         1
# promotion_last_5years        0
# sales                    sales
# salary                     low
# Name: 8, dtype: object

# %% [markdown]
# # The most satisfied worker however works 60 hours less than the guy in sales and has only spent 3 years at the company, they both seem pretty happy relatively.

# %%
Out['372b0d'].iloc[Out['372b0d']['satisfaction_level'].idxmax()]
# Out:
# satisfaction_level               1
# last_evaluation               0.41
# number_project                   4
# average_montly_hours           174
# time_spend_company               3
# Work_accident                    0
# left                             0
# promotion_last_5years            0
# sales                    technical
# salary                         low
# Name: 2023, dtype: object

# %%
Out['372b0d'].groupby("sales").mean()
# Out:
#              satisfaction_level  last_evaluation  number_project  \
# sales
# IT                     0.618142         0.716830        3.816626
# RandD                  0.619822         0.712122        3.853875
# accounting             0.582151         0.717718        3.825293
# hr                     0.598809         0.708850        3.654939
# management             0.621349         0.724000        3.860317
# marketing              0.618601         0.715886        3.687646
# product_mng            0.619634         0.714756        3.807095
# sales                  0.614447         0.709717        3.776329
# support                0.618300         0.723109        3.803948
# technical              0.607897         0.721099        3.877941
#
#              average_montly_hours  time_spend_company  Work_accident  \
# sales
# IT                     202.215974            3.468623       0.133659
# RandD                  200.800508            3.367217       0.170267
# ...

# %% [markdown]
# # Maybe we want to take a look and see if there's any correlation between the number of workplace accidents and the number of monthly hours that an employee has worked.

# %%
# %matplotlib inline
Out['7dc400'].plot.scatter(x='Work_accident',y='average_montly_hours')

# %%
Out['372b0d'].groupby("salary").count()
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# salary
# high                  1237             1237            1237
# low                   7316             7316            7316
# medium                6446             6446            6446
#
#         average_montly_hours  time_spend_company  Work_accident  left  \
# salary
# high                    1237                1237           1237  1237
# low                     7316                7316           7316  7316
# medium                  6446                6446           6446  6446
#
#         promotion_last_5years  sales
# salary
# high                     1237   1237
# low                      7316   7316
# medium                   6446   6446

# %% [markdown]
# # One of the most interesting things to come out of this company is that they don't appear to have very much upward mobility. If you're on the high side of salary you have a relatively decent chance of recieving a promotion, but if you're on the lower end of employment forget about recieving a raise anytime soon.

# %%
Out['372b0d'].groupby("salary").mean()
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# salary
# high              0.637470         0.704325        3.767179
# low               0.600753         0.717017        3.799891
# medium            0.621817         0.717322        3.813528
#
#         average_montly_hours  time_spend_company  Work_accident      left  \
# salary
# high              199.867421            3.692805       0.155214  0.066289
# low               200.996583            3.438218       0.142154  0.296884
# medium            201.338349            3.529010       0.145361  0.204313
#
#         promotion_last_5years
# salary
# high                 0.058205
# low                  0.009021
# medium               0.028079

# %%
import pandas as pd
pd.read_csv("HR_comma_sep.csv")
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...
