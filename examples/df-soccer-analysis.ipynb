# %%
# %matplotlib inline
Out['b0941f'].plot(kind="bar")

# %%
import pandas as pd
pd.read_csv("fifa17-top20-women-fixed.txt",sep="-",header=None)
# Out:
#                          0          1   2
# 0          Caroline Seger     Sweden   85
# 1           Wendie Renard     France   85
# 2          Steph Houghton    England   85
# 3          Sophie Schmidt     Canada   85
# 4             Erin McLeod     Canada   85
# 5                  Rosana     Brazil   85
# 6               Cristiane     Brazil   85
# 7          Julie Johnston        USA   86
# 8             Tobin Heath        USA   86
# 9             Alex Morgan        USA   86
# 10          Nilla Fischer     Sweden   86
# 11     Dzsenifer Marozsan    Germany   86
# 12         Alexandra Popp    Germany   86
# 13       Becky Sauerbrunn        USA   87
# 14  Ada Stolsmo Hegerberg     Norway   88
# 15         Amandine Henry     France   88
# 16     Christine Sinclair     Canada   89
# 17                  Marta     Brazil   89
# 18          Megan Rapinoe        USA   91
# 19            Carli Lloyd        USA   92

# %%
Out['8df897'].rename(columns={0: "Name", 1: "Country", 
                              2: "Rating"})
# Out:
#                       Name    Country  Rating
# 0          Caroline Seger     Sweden       85
# 1           Wendie Renard     France       85
# 2          Steph Houghton    England       85
# 3          Sophie Schmidt     Canada       85
# 4             Erin McLeod     Canada       85
# 5                  Rosana     Brazil       85
# 6               Cristiane     Brazil       85
# 7          Julie Johnston        USA       86
# 8             Tobin Heath        USA       86
# 9             Alex Morgan        USA       86
# 10          Nilla Fischer     Sweden       86
# 11     Dzsenifer Marozsan    Germany       86
# 12         Alexandra Popp    Germany       86
# 13       Becky Sauerbrunn        USA       87
# 14  Ada Stolsmo Hegerberg     Norway       88
# 15         Amandine Henry     France       88
# 16     Christine Sinclair     Canada       89
# 17                  Marta     Brazil       89
# 18          Megan Rapinoe        USA       91
# ...

# %%
Out['7dd314'].groupby("Country").count()
# Out:
#            Name  Rating
# Country
#  Brazil       3       3
#  Canada       3       3
#  England      1       1
#  France       2       2
#  Germany      2       2
#  Norway       1       1
#  Sweden       2       2
#  USA          6       6

# %%
df = Out['7dd314']
df[df["Country"] == "USA"]
# Out:
# Empty DataFrame
# Columns: [Name, Country, Rating]
# Index: []

# %%
df = Out['7dd314']
df.assign(Name=df["Name"].str.strip(), 
          Country=df["Country"].str.strip())
# Out:
#                      Name  Country  Rating
# 0          Caroline Seger   Sweden      85
# 1           Wendie Renard   France      85
# 2          Steph Houghton  England      85
# 3          Sophie Schmidt   Canada      85
# 4             Erin McLeod   Canada      85
# 5                  Rosana   Brazil      85
# 6               Cristiane   Brazil      85
# 7          Julie Johnston      USA      86
# 8             Tobin Heath      USA      86
# 9             Alex Morgan      USA      86
# 10          Nilla Fischer   Sweden      86
# 11     Dzsenifer Marozsan  Germany      86
# 12         Alexandra Popp  Germany      86
# 13       Becky Sauerbrunn      USA      87
# 14  Ada Stolsmo Hegerberg   Norway      88
# 15         Amandine Henry   France      88
# 16     Christine Sinclair   Canada      89
# 17                  Marta   Brazil      89
# 18          Megan Rapinoe      USA      91
# 19            Carli Lloyd      USA      92

# %%
df = Out['3fbfcd']
df[df["Country"] == "USA"]

# %%
Out['3fbfcd'].groupby("Country")["Country"].count().sort_values()
# Out:
# Country
# England    1
# Norway     1
# France     2
# Germany    2
# Sweden     2
# Brazil     3
# Canada     3
# USA        6
# Name: Country, dtype: int64
